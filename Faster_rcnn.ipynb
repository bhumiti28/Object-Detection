# %% [markdown]
# <a href="https://colab.research.google.com/github/bhumiti28/Object-Detection/blob/main/Faster_rcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Unzip data

# %%
# %cd '/content/drive/MyDrive/Cv_Assignment_8/images'
# Out:
# /content/drive/MyDrive/Cv_Assignment_8/images

# %%
# !unzip /content/drive/MyDrive/Cv_Assignment_8/Tomato.v3-tomato_new.voc.zip
# Out:
# Archive:  /content/drive/MyDrive/Cv_Assignment_8/Tomato.v3-tomato_new.voc.zip
#  extracting: README.roboflow.txt
#    creating: test/
#  extracting: test/002_18_jpg.rf.9330839c94a38f36656ecd0e4b48c172.jpg
#  extracting: test/002_18_jpg.rf.9330839c94a38f36656ecd0e4b48c172.xml
#  extracting: test/003_11_jpg.rf.f5b2c55b9221e61abaec0efe6c7cc0ee.jpg
#  extracting: test/003_11_jpg.rf.f5b2c55b9221e61abaec0efe6c7cc0ee.xml
#  extracting: test/003_18_jpg.rf.739a37e8efe84693fd433c53db34e77a.jpg
#  extracting: test/003_18_jpg.rf.739a37e8efe84693fd433c53db34e77a.xml
#  extracting: test/003_21_jpg.rf.43750f18edf11c95c6a5d12bd7c3e39a.jpg
#  extracting: test/003_21_jpg.rf.43750f18edf11c95c6a5d12bd7c3e39a.xml
#  extracting: test/003_2_jpg.rf.e8631af30e54a1a09760c8f59d0bd02b.jpg
#  extracting: test/003_2_jpg.rf.e8631af30e54a1a09760c8f59d0bd02b.xml
#  extracting: test/003_6_jpg.rf.6752da91d627fb6f4b19e54602bb4068.jpg
#  extracting: test/003_6_jpg.rf.6752da91d627fb6f4b19e54602bb4068.xml
# ...

# %% [markdown]
# ## Setting path

# %%
# %cd '/content/drive/MyDrive/Cv_Assignment_8/TensorFlow'
# Out:
# /content/drive/MyDrive/Cv_Assignment_8/TensorFlow

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 973, done.
# remote: Counting objects: 100% (973/973), done.
# remote: Compressing objects: 100% (491/491), done.
# remote: Total 55645 (delta 588), reused 815 (delta 470), pack-reused 54672
# Receiving objects: 100% (55645/55645), 572.07 MiB | 15.20 MiB/s, done.
# Resolving deltas: 100% (38200/38200), done.
# Checking out files: 100% (2394/2394), done.

# %%
# %cd '/content/drive/MyDrive/Cv_Assignment_8/TensorFlow/models'
# Out:
# /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/models

# %%
# !git branch
# !git checkout -f e04dafd04d69053d3733bb91d47d0d95bc2c8199
# Out:
# * master
# Checking out files: 100% (1230/1230), done.
# Note: checking out 'e04dafd04d69053d3733bb91d47d0d95bc2c8199'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at e04dafd0 Add copybara presumbit metadata, and move files to root dir.

# %%
# !apt-get install protobuf-compiler python-lxml python-pil
# !pip install Cython
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 31 not upgraded.
# Need to get 1,614 kB of archives.
# After this operation, 8,907 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# ...

# %%
# !pip install tf_slim
# Out:
# ...
#      |████████████████████████████████| 358kB 16.9MB/s
# ...

# %%
# %cd '/content/drive/MyDrive/Cv_Assignment_8/TensorFlow/models/research'
# Out:
# /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
import sys

os.environ['PYTHONPATH']+=":/content/drive/MyDrive/Cv_Assignment_8/TensorFlow/models"

sys.path.append("/content/drive/MyDrive/Cv_Assignment_8/TensorFlow/models/research")

# %%
# !python setup.py build
# !python setup.py install
# Out:
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/object_detection
# copying object_detection/__init__.py -> build/lib/object_detection
# copying object_detection/eval_util.py -> build/lib/object_detection
# copying object_detection/eval_util_test.py -> build/lib/object_detection
# copying object_detection/export_inference_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_graph_lib_tf2.py -> build/lib/object_detection
# copying object_detection/export_tflite_graph_lib_tf2_test.py -> build/lib/object_detection
# copying object_detection/export_tflite_graph_tf2.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib_tf1_test.py -> build/lib/object_detection
# ...

# %%
# %cd '/content/drive/MyDrive/Cv_Assignment_8/TensorFlow/models/research/object_detection/builders/'
# Out:
# /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/models/research/object_detection/builders

# %%
# !python model_builder_tf2_test.py
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
print('Finished!!!!')
# Out:
# 2021-04-12 18:59:10.318332: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Running tests under Python 3.7.10: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model
# 2021-04-12 18:59:14.769362: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-12 18:59:14.787645: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-12 18:59:14.852146: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-04-12 18:59:14.852208: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e66f890b2407): /proc/driver/nvidia/version does not exist
# ...

# %%
# %cd '/content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/scripts/'
# Out:
# /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/scripts

# %%
# %ls
# Out:
# exporter_main_v2.py       generate_tfrecord.py  partition_dataset.py
# generate_tfrecord_csv.py  model_main_tf2.py

# %% [markdown]
# ## Partition dataset test and train

# %%
# !python3 partition_dataset.py -x -i /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/images -r 0.1

# %% [markdown]
# ## split train

# %%
# !python3 generate_tfrecord.py -x /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/images/train -l /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/annotations/label_map.pbtxt -o /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/annotations/train.record -c /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/annotations/train.csv
# Out:
# Traceback (most recent call last):
#   File "generate_tfrecord.py", line 169, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.7/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "generate_tfrecord.py", line 156, in main
#     examples = xml_to_csv(args.xml_dir)
#   File "generate_tfrecord.py", line 88, in xml_to_csv
#     int(member[4][0].text),
# IndexError: child index out of range

# %% [markdown]
# ## split test

# %%
# !python3 generate_tfrecord.py -x /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/images/test -l /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/annotations/label_map.pbtxt -o /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/annotations/test.record -c /content/drive/MyDrive/Cv_Assignment_8/TensorFlow/Project/annotations/test.csv
